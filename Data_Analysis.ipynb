# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('/Users/padhmapriya/Downloads/Crimes_-_2001_to_Present.csv')
print('File Read Succesfully')
# Out:
# File Read Succesfully

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data.tail()
# Out:
#                ID Case Number                Date                   Block  \
# 8077146  13047495    JG229914 2023-04-18 08:00:00    003XX N JEFFERSON ST
# 8077147  13168300    JG373901 2023-08-07 18:00:00         0000X W 95TH ST
# 8077148  13114024    JG309527 2023-06-20 19:00:00       031XX S AVERS AVE
# 8077149  13188860    JG398340 2023-08-26 00:00:00  078XX S SOUTH SHORE DR
# 8077150  13126372    JG324067 2023-07-01 19:29:00        005XX S WELLS ST
#
#          IUCR         Primary Type                              Description  \
# 8077146  1154   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 8077147  031A              ROBBERY                          ARMED - HANDGUN
# 8077148  0910  MOTOR VEHICLE THEFT                               AUTOMOBILE
# 8077149  1320      CRIMINAL DAMAGE                               TO VEHICLE
# 8077150  1320      CRIMINAL DAMAGE                               TO VEHICLE
#
#         Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 8077146            APARTMENT   False     False  ...  42.0            28.0
# 8077147             SIDEWALK   False     False  ...   9.0            49.0
# 8077148               STREET   False     False  ...  22.0            30.0
# 8077149               STREET   False     False  ...   7.0            46.0
# 8077150               STREET   False      True  ...  34.0            32.0
#
#          FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 8077146        11     1172269.0    1902384.0  2023  08/19/2023 03:40:26 PM
# 8077147        03     1177527.0    1841973.0  2023  08/19/2023 03:40:26 PM
# 8077148        07     1151205.0    1883542.0  2023  08/19/2023 03:40:26 PM
# 8077149        14     1198338.0    1853426.0  2023  09/02/2023 03:41:45 PM
# 8077150        14     1174805.0    1897873.0  2023  08/19/2023 03:40:26 PM
#
#           Latitude  Longitude                       Location
# 8077146  41.887589 -87.642827  (41.887589411, -87.642826595)
# 8077147  41.721698 -87.625345   (41.72169837, -87.625345212)
# 8077148  41.836324 -87.720674  (41.836323827, -87.720674149)
# 8077149  41.752631 -87.548737  (41.752631346, -87.548737069)
# 8077150  41.875155 -87.633649   (41.87515458, -87.633648765)
#
# [5 rows x 22 columns]

# %%
data.index= pd.DatetimeIndex(data.Date)
data.index = pd.to_datetime(data.index)

# %%
data['Primary Type'] = pd.Categorical(data['Primary Type'])
data['Description'] = pd.Categorical(data['Description'])
data['Location Description'] = pd.Categorical(data['Location Description'])

# %%
data['Primary Type']
# Out:
# Date
# 2007-08-25 09:22:18                ASSAULT
# 2021-05-24 15:06:00               HOMICIDE
# 2021-06-26 09:24:00               HOMICIDE
# 2023-11-09 07:30:00               BURGLARY
# 2023-11-12 07:59:00                BATTERY
#                               ...
# 2023-04-18 08:00:00     DECEPTIVE PRACTICE
# 2023-08-07 18:00:00                ROBBERY
# 2023-06-20 19:00:00    MOTOR VEHICLE THEFT
# 2023-08-26 00:00:00        CRIMINAL DAMAGE
# 2023-07-01 19:29:00        CRIMINAL DAMAGE
# Name: Primary Type, Length: 8077151, dtype: category
# Categories (36, object): ['ARSON', 'ASSAULT', 'BATTERY', 'BURGLARY', ..., 'SEX OFFENSE', 'STALKING', 'THEFT', 'WEAPONS VIOLATION']

# %%
data.tail()
# Out:
#                            ID Case Number                Date  \
# Date
# 2023-04-18 08:00:00  13047495    JG229914 2023-04-18 08:00:00
# 2023-08-07 18:00:00  13168300    JG373901 2023-08-07 18:00:00
# 2023-06-20 19:00:00  13114024    JG309527 2023-06-20 19:00:00
# 2023-08-26 00:00:00  13188860    JG398340 2023-08-26 00:00:00
# 2023-07-01 19:29:00  13126372    JG324067 2023-07-01 19:29:00
#
#                                       Block  IUCR         Primary Type  \
# Date
# 2023-04-18 08:00:00    003XX N JEFFERSON ST  1154   DECEPTIVE PRACTICE
# 2023-08-07 18:00:00         0000X W 95TH ST  031A              ROBBERY
# 2023-06-20 19:00:00       031XX S AVERS AVE  0910  MOTOR VEHICLE THEFT
# 2023-08-26 00:00:00  078XX S SOUTH SHORE DR  1320      CRIMINAL DAMAGE
# 2023-07-01 19:29:00        005XX S WELLS ST  1320      CRIMINAL DAMAGE
#
#                                                  Description  \
# Date
# 2023-04-18 08:00:00  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2023-08-07 18:00:00                          ARMED - HANDGUN
# 2023-06-20 19:00:00                               AUTOMOBILE
# 2023-08-26 00:00:00                               TO VEHICLE
# 2023-07-01 19:29:00                               TO VEHICLE
#
#                     Location Description  Arrest  Domestic  ...  Ward  \
# Date                                                        ...
# 2023-04-18 08:00:00            APARTMENT   False     False  ...  42.0
# 2023-08-07 18:00:00             SIDEWALK   False     False  ...   9.0
# 2023-06-20 19:00:00               STREET   False     False  ...  22.0
# 2023-08-26 00:00:00               STREET   False     False  ...   7.0
# 2023-07-01 19:29:00               STREET   False      True  ...  34.0
#
#                      Community Area  FBI Code  X Coordinate Y Coordinate  \
# Date
# 2023-04-18 08:00:00            28.0        11     1172269.0    1902384.0
# 2023-08-07 18:00:00            49.0        03     1177527.0    1841973.0
# 2023-06-20 19:00:00            30.0        07     1151205.0    1883542.0
# 2023-08-26 00:00:00            46.0        14     1198338.0    1853426.0
# 2023-07-01 19:29:00            32.0        14     1174805.0    1897873.0
#
#                      Year              Updated On   Latitude  Longitude  \
# Date
# 2023-04-18 08:00:00  2023  08/19/2023 03:40:26 PM  41.887589 -87.642827
# 2023-08-07 18:00:00  2023  08/19/2023 03:40:26 PM  41.721698 -87.625345
# 2023-06-20 19:00:00  2023  08/19/2023 03:40:26 PM  41.836324 -87.720674
# 2023-08-26 00:00:00  2023  09/02/2023 03:41:45 PM  41.752631 -87.548737
# 2023-07-01 19:29:00  2023  08/19/2023 03:40:26 PM  41.875155 -87.633649
#
#                                           Location
# Date
# 2023-04-18 08:00:00  (41.887589411, -87.642826595)
# 2023-08-07 18:00:00   (41.72169837, -87.625345212)
# 2023-06-20 19:00:00  (41.836323827, -87.720674149)
# 2023-08-26 00:00:00  (41.752631346, -87.548737069)
# 2023-07-01 19:29:00   (41.87515458, -87.633648765)
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.year]).size().plot.line()
plt.title('Crime Over the Years')
plt.xlabel('Year')
plt.ylabel('No. of Crimes ')
plt.show()

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.month]).size().plot.bar()
plt.title('Crime Per Month')
plt.xlabel('Month')
plt.ylabel('No. of Crimes ')
plt.show()

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.day]).size().plot.bar()
plt.title('Crime Per Day Of Month')
plt.xlabel('Day')
plt.ylabel('No. of Crimes ')
plt.show()

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.hour]).size().plot.bar()
plt.title('Crime Per Hour')
plt.xlabel('Hour')
plt.ylabel('No. of Crimes ')
# %matplotlib qt                    //This command doesn't work on virtual environments like Google Colabs 
plt.show()

# %%
crimes_count_date = data.pivot_table('ID', aggfunc=np.size, columns='Primary Type', index=data.index.date, fill_value=0)
crimes_count_date.index = pd.DatetimeIndex(crimes_count_date.index)
plo = crimes_count_date.rolling(365).sum().plot(figsize=(50, 50), subplots=True, layout=(-1, 3), sharex=False, sharey=False)
# %matplotlib qt                    //This command doesn't work on virtual environments like Google Colabs
